# %% [markdown]
# <a href="https://colab.research.google.com/github/alwjr-hccs/ITAI_ML_FirstRepo_AWilliams/blob/main/PastHires.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path="/content/drive/MyDrive/Dataset/PastHires.csv"
df=pd.read_csv(path)
df.head()
# Out:
#    Years Experience Employed?  Previous employers Level of Education  \
# 0                10         Y                   4                 BS
# 1                 0         N                   0                 BS
# 2                 7         N                   6                 BS
# 3                 2         Y                   1                 MS
# 4                20         N                   2                PhD
#
#   Top-tier school Interned Hired
# 0               N        N     Y
# 1               Y        Y     Y
# 2               N        N     N
# 3               Y        N     Y
# 4               Y        N     N

# %%
import pandas as pd

# %%
path="/content/drive/MyDrive/Dataset/PastHires.csv"
